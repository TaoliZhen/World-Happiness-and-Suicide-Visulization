# %%
pip install country_converter
# Out:
# Processing /Users/Felicia/Library/Caches/pip/wheels/44/5a/d0/9f8289ce8e394f317bb0bc304e6f22ec2b19031b0c92c6f0cb/country_converter-0.7.3-py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import country_converter as coco

# %% [markdown]
# ## World Happiness score
# ### File name: 'HappinessDataPanelWHR2021C2.csv'
# link: https://worldhappiness.report/ed/2021/#appendices-and-data

# %%
happiness = pd.read_csv("HappinessDataPanelWHR2021C2.csv")

# %% [markdown]
# ### Check data types and values

# %%
happiness.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.154084        0.118482
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.464000        0.749750
# 50%    2013.000000     5.386000            9.460000        0.835500
# 75%    2017.000000     6.283000           10.353000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359374                      0.742558
# std                            7.510245                      0.142093
# min                           32.300000                      0.258000
# ...

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %% [markdown]
# ### Get country region

# %%
country_region = pd.read_csv("all_country_regions.csv")
#country_region = country_region.rename(columns={"name":"Country", "alpha-3":"CountryCode"})
#country_region['intermediate-region-code'] = country_region['intermediate-region-code'].fillna(country_region['sub-region-code'])

# %%
country_region
# Out:
#                Country CountryCode  country-code     iso_3166-2   region  \
# 0          Afghanistan         AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands         ALA           248  ISO 3166-2:AX   Europe
# 2              Albania         ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria         DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa         ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...         ...           ...            ...      ...
# 244  Wallis and Futuna         WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara         ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen         YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia         ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe         ZWE           716  ISO 3166-2:ZW   Africa
#
#           sub-region  region-code  sub-region-code
# ...

# %%
happiness["Country name"] = coco.convert(names = happiness["Country name"], to="name_short")
happiness
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
happiness.to_csv("HappinessCleaned.csv")

# %% [markdown]
# Countries with null in regional indicator

# %%
happiness_cleaned = pd.read_csv("HappinessCleaned.csv")
happiness_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        1949 non-null   int64
#  1   Country name                      1949 non-null   object
#  2   year                              1949 non-null   int64
#  3   Life Ladder                       1949 non-null   float64
#  4   Log GDP per capita                1913 non-null   float64
#  5   Social support                    1936 non-null   float64
#  6   Healthy life expectancy at birth  1894 non-null   float64
#  7   Freedom to make life choices      1917 non-null   float64
#  8   Generosity                        1860 non-null   float64
#  9   Perceptions of corruption         1839 non-null   float64
#  10  Positive affect                   1927 non-null   float64
# ...
